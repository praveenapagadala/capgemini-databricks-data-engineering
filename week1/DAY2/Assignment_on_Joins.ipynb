-- %%
CREATE TABLE employees ( 
emp_id INT PRIMARY KEY, 
emp_name VARCHAR(50), 
manager_id INT, 
dept_id INT 
); 
INSERT INTO employees (emp_id, emp_name, manager_id, dept_id) VALUES 
(1, 'Karthik', NULL, 1), 
(2, 'Ajay', 1, 1), 
(3, 'Vijay', 1, 2), 
(4, 'Vinay', 2, 2), 
(5, 'Meena', 3, 3), 
(6, 'Veer', NULL, 4), 
(7, 'Keerthi', 4, 5), 
(8, 'Priya', 4, 5); 
 

--Table: departments 
CREATE TABLE departments ( 
dept_id INT PRIMARY KEY, 
dept_name VARCHAR(50) 

); 
 

INSERT INTO departments (dept_id, dept_name) VALUES 
(1, 'HR'), 
(2, 'IT'), 
(3, 'Finance'), 
(4, 'Marketing'), 
(5, 'Sales'); 
 

--Table: projects 
CREATE TABLE projects ( 
project_id INT PRIMARY KEY, 
project_name VARCHAR(50), 
emp_id INT 
); 
 

INSERT INTO projects (project_id, project_name, emp_id) VALUES 
(1, 'Project A', 1), 
(2, 'Project B', 2), 
(3, 'Project C', 3), 
(4, 'Project D', 4), 
(5, 'Project E', 5);
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>num_affected_rows</th><th>num_inserted_rows</th></tr></thead><tbody><tr><td>5</td><td>5</td></tr></tbody></table></div>

-- %%
--1
select e.emp_name,e.manager_id from employees e join employees m on e.emp_id=m.emp_id ;
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>emp_name</th><th>manager_id</th></tr></thead><tbody><tr><td>Karthik</td><td>null</td></tr><tr><td>Ajay</td><td>1</td></tr><tr><td>Vijay</td><td>1</td></tr><tr><td>Vinay</td><td>2</td></tr><tr><td>Meena</td><td>3</td></tr><tr><td>Veer</td><td>null</td></tr><tr><td>Keerthi</td><td>4</td></tr><tr><td>Priya</td><td>4</td></tr></tbody></table></div>

-- %%
--2
select e.emp_name,d.dept_name from employees e left join departments d on e.dept_id=d.dept_id;
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>emp_name</th><th>dept_name</th></tr></thead><tbody><tr><td>Karthik</td><td>HR</td></tr><tr><td>Ajay</td><td>HR</td></tr><tr><td>Vijay</td><td>IT</td></tr><tr><td>Vinay</td><td>IT</td></tr><tr><td>Meena</td><td>Finance</td></tr><tr><td>Veer</td><td>Marketing</td></tr><tr><td>Keerthi</td><td>Sales</td></tr><tr><td>Priya</td><td>Sales</td></tr></tbody></table></div>

-- %%
--3
select e.emp_name, m.manager_id
from employees e
join employees m on e.manager_id = m.emp_id;
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>emp_name</th><th>manager_id</th></tr></thead><tbody><tr><td>Ajay</td><td>null</td></tr><tr><td>Vijay</td><td>null</td></tr><tr><td>Vinay</td><td>1</td></tr><tr><td>Meena</td><td>1</td></tr><tr><td>Keerthi</td><td>2</td></tr><tr><td>Priya</td><td>2</td></tr></tbody></table></div>

-- %%
select e.emp_name
from employees e
left join departments d on e.dept_id = d.dept_id
where d.dept_id is null;
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>emp_name</th></tr></thead><tbody></tbody></table></div>

-- %%
--6
select e.emp_name,p.project_name from employees e left join projects p on e.emp_id=p.emp_id;
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>emp_name</th><th>project_name</th></tr></thead><tbody><tr><td>Karthik</td><td>Project A</td></tr><tr><td>Ajay</td><td>Project B</td></tr><tr><td>Vijay</td><td>Project C</td></tr><tr><td>Vinay</td><td>Project D</td></tr><tr><td>Meena</td><td>Project E</td></tr><tr><td>Veer</td><td>null</td></tr><tr><td>Keerthi</td><td>null</td></tr><tr><td>Priya</td><td>null</td></tr></tbody></table></div>

-- %%
--7* 
select e.emp_name,p.project_name from employees e left join projects p on e.emp_id=p.emp_id group by e.emp_name,p.project_name having count(p.project_id)>=1;
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>emp_name</th><th>project_name</th></tr></thead><tbody><tr><td>Karthik</td><td>Project A</td></tr><tr><td>Ajay</td><td>Project B</td></tr><tr><td>Vinay</td><td>Project D</td></tr><tr><td>Vijay</td><td>Project C</td></tr><tr><td>Meena</td><td>Project E</td></tr></tbody></table></div>

-- %%
--8
select e.emp_name, p.project_name from employees e
right join Projects p on e.emp_id = p.emp_id;
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>emp_name</th><th>project_name</th></tr></thead><tbody><tr><td>Karthik</td><td>Project A</td></tr><tr><td>Ajay</td><td>Project B</td></tr><tr><td>Vijay</td><td>Project C</td></tr><tr><td>Vinay</td><td>Project D</td></tr><tr><td>Meena</td><td>Project E</td></tr></tbody></table></div>

-- %%
--10
select e.emp_name,d.dept_name from employees e left join departments d on e.dept_id=d.dept_id;
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>emp_name</th><th>dept_name</th></tr></thead><tbody><tr><td>Karthik</td><td>HR</td></tr><tr><td>Ajay</td><td>HR</td></tr><tr><td>Vijay</td><td>IT</td></tr><tr><td>Vinay</td><td>IT</td></tr><tr><td>Meena</td><td>Finance</td></tr><tr><td>Veer</td><td>Marketing</td></tr><tr><td>Keerthi</td><td>Sales</td></tr><tr><td>Priya</td><td>Sales</td></tr></tbody></table></div>

-- %%
--11
select e.emp_name,d.dept_name from employees e right join departments d on e.dept_id=d.dept_id;
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>emp_name</th><th>dept_name</th></tr></thead><tbody><tr><td>Ajay</td><td>HR</td></tr><tr><td>Vinay</td><td>IT</td></tr><tr><td>Meena</td><td>Finance</td></tr><tr><td>Veer</td><td>Marketing</td></tr><tr><td>Priya</td><td>Sales</td></tr><tr><td>Karthik</td><td>HR</td></tr><tr><td>Vijay</td><td>IT</td></tr><tr><td>Keerthi</td><td>Sales</td></tr></tbody></table></div>

-- %%
--13
select e.emp_name,d.dept_name from employees e full  join departments d on e.dept_id=d.dept_id;
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>emp_name</th><th>dept_name</th></tr></thead><tbody><tr><td>Keerthi</td><td>Sales</td></tr><tr><td>Priya</td><td>Sales</td></tr><tr><td>Karthik</td><td>HR</td></tr><tr><td>Ajay</td><td>HR</td></tr><tr><td>Meena</td><td>Finance</td></tr><tr><td>Vijay</td><td>IT</td></tr><tr><td>Vinay</td><td>IT</td></tr><tr><td>Veer</td><td>Marketing</td></tr></tbody></table></div>

-- %%
select e.emp_name
from employees e
left join projects p on e.emp_id = p.emp_id
where p.project_id is null;
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>emp_name</th></tr></thead><tbody><tr><td>Veer</td></tr><tr><td>Keerthi</td></tr><tr><td>Priya</td></tr></tbody></table></div>

-- %%
--15
select e.emp_name,p.project_name from employees e left join projects p on e.emp_id=p.emp_id;
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>emp_name</th><th>project_name</th></tr></thead><tbody><tr><td>Karthik</td><td>Project A</td></tr><tr><td>Ajay</td><td>Project B</td></tr><tr><td>Vijay</td><td>Project C</td></tr><tr><td>Vinay</td><td>Project D</td></tr><tr><td>Meena</td><td>Project E</td></tr><tr><td>Veer</td><td>null</td></tr><tr><td>Keerthi</td><td>null</td></tr><tr><td>Priya</td><td>null</td></tr></tbody></table></div>

-- %%
--16 
select e.emp_name,p.project_name from employees e right join projects p on e.emp_id=p.emp_id;
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>emp_name</th><th>project_name</th></tr></thead><tbody><tr><td>Karthik</td><td>Project A</td></tr><tr><td>Ajay</td><td>Project B</td></tr><tr><td>Vijay</td><td>Project C</td></tr><tr><td>Vinay</td><td>Project D</td></tr><tr><td>Meena</td><td>Project E</td></tr></tbody></table></div>

-- %%
--17
select e1.emp_name,e2.manager_id,p.project_name from employees e1 join employees e2 on e1.emp_id=e2.emp_id join projects p on e1.emp_id=p.emp_id;
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>emp_name</th><th>manager_id</th><th>project_name</th></tr></thead><tbody><tr><td>Karthik</td><td>null</td><td>Project A</td></tr><tr><td>Ajay</td><td>1</td><td>Project B</td></tr><tr><td>Vijay</td><td>1</td><td>Project C</td></tr><tr><td>Vinay</td><td>2</td><td>Project D</td></tr><tr><td>Meena</td><td>3</td><td>Project E</td></tr></tbody></table></div>

-- %%
--18
select e.emp_name,d.dept_name from employees e join departments d on e.dept_id=d.dept_id;
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>emp_name</th><th>dept_name</th></tr></thead><tbody><tr><td>Karthik</td><td>HR</td></tr><tr><td>Ajay</td><td>HR</td></tr><tr><td>Vijay</td><td>IT</td></tr><tr><td>Vinay</td><td>IT</td></tr><tr><td>Meena</td><td>Finance</td></tr><tr><td>Veer</td><td>Marketing</td></tr><tr><td>Keerthi</td><td>Sales</td></tr><tr><td>Priya</td><td>Sales</td></tr></tbody></table></div>

-- %%
--19
select e.emp_name,d.dept_name from employees e join departments d on e.dept_id=d.dept_id;
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>emp_name</th><th>dept_name</th></tr></thead><tbody><tr><td>Karthik</td><td>HR</td></tr><tr><td>Ajay</td><td>HR</td></tr><tr><td>Vijay</td><td>IT</td></tr><tr><td>Vinay</td><td>IT</td></tr><tr><td>Meena</td><td>Finance</td></tr><tr><td>Veer</td><td>Marketing</td></tr><tr><td>Keerthi</td><td>Sales</td></tr><tr><td>Priya</td><td>Sales</td></tr></tbody></table></div>

-- %%
--20
select d.dept_name,e.emp_name from employees e right join departments d on e.dept_id=d.dept_id;
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>dept_name</th><th>emp_name</th></tr></thead><tbody><tr><td>HR</td><td>Ajay</td></tr><tr><td>IT</td><td>Vinay</td></tr><tr><td>Finance</td><td>Meena</td></tr><tr><td>Marketing</td><td>Veer</td></tr><tr><td>Sales</td><td>Priya</td></tr><tr><td>HR</td><td>Karthik</td></tr><tr><td>IT</td><td>Vijay</td></tr><tr><td>Sales</td><td>Keerthi</td></tr></tbody></table></div>

-- %%
--21
select e.emp_name,p.project_name from employees e  join projects p on e.emp_id=p.emp_id left join departments d on e.dept_id=d.dept_id
where d.dept_id is null;
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>emp_name</th><th>project_name</th></tr></thead><tbody></tbody></table></div>

-- %%
--22
select d.dept_name, count(e.emp_id) as total_employees
from departments d
left join employees e on d.dept_id = e.dept_id
group by d.dept_name;
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>dept_name</th><th>total_employees</th></tr></thead><tbody><tr><td>Sales</td><td>2</td></tr><tr><td>IT</td><td>2</td></tr><tr><td>HR</td><td>2</td></tr><tr><td>Finance</td><td>1</td></tr><tr><td>Marketing</td><td>1</td></tr></tbody></table></div>

-- %%
--23
select e.emp_name, m.manager_id
from employees e
join employees m on e.emp_id = m.emp_id;
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>emp_name</th><th>manager_id</th></tr></thead><tbody><tr><td>Karthik</td><td>null</td></tr><tr><td>Ajay</td><td>1</td></tr><tr><td>Vijay</td><td>1</td></tr><tr><td>Vinay</td><td>2</td></tr><tr><td>Meena</td><td>3</td></tr><tr><td>Veer</td><td>null</td></tr><tr><td>Keerthi</td><td>4</td></tr><tr><td>Priya</td><td>4</td></tr></tbody></table></div>

-- %%
--24
select e.emp_name, m.manager_id
from employees e
left join employees m on e.emp_id = m.emp_id;
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>emp_name</th><th>manager_id</th></tr></thead><tbody><tr><td>Karthik</td><td>null</td></tr><tr><td>Ajay</td><td>1</td></tr><tr><td>Vijay</td><td>1</td></tr><tr><td>Vinay</td><td>2</td></tr><tr><td>Meena</td><td>3</td></tr><tr><td>Veer</td><td>null</td></tr><tr><td>Keerthi</td><td>4</td></tr><tr><td>Priya</td><td>4</td></tr></tbody></table></div>

-- %%
--25
select d.dept_name, count(e.emp_id) as employee_count
from departments d
left join employees e on d.dept_id = e.dept_id
group by d.dept_name;
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>dept_name</th><th>employee_count</th></tr></thead><tbody><tr><td>Sales</td><td>2</td></tr><tr><td>IT</td><td>2</td></tr><tr><td>HR</td><td>2</td></tr><tr><td>Finance</td><td>1</td></tr><tr><td>Marketing</td><td>1</td></tr></tbody></table></div>

-- %%
--26
select e.emp_name, d.dept_name
from departments d
left join employees e on d.dept_id = e.dept_id;
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>emp_name</th><th>dept_name</th></tr></thead><tbody><tr><td>Ajay</td><td>HR</td></tr><tr><td>Vinay</td><td>IT</td></tr><tr><td>Meena</td><td>Finance</td></tr><tr><td>Veer</td><td>Marketing</td></tr><tr><td>Priya</td><td>Sales</td></tr><tr><td>Karthik</td><td>HR</td></tr><tr><td>Vijay</td><td>IT</td></tr><tr><td>Keerthi</td><td>Sales</td></tr></tbody></table></div>

-- %%
--27
select e.emp_name
from employees e
left join salary s on e.emp_id = s.emp_id
where s.salary is null;

-- %%
select e.emp_name, p.project_name
from employees e
left join projects p on e.emp_id = p.emp_id;
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>emp_name</th><th>project_name</th></tr></thead><tbody><tr><td>Karthik</td><td>Project A</td></tr><tr><td>Ajay</td><td>Project B</td></tr><tr><td>Vijay</td><td>Project C</td></tr><tr><td>Vinay</td><td>Project D</td></tr><tr><td>Meena</td><td>Project E</td></tr><tr><td>Veer</td><td>null</td></tr><tr><td>Keerthi</td><td>null</td></tr><tr><td>Priya</td><td>null</td></tr></tbody></table></div>

-- %%
--29
select e.emp_name, d.dept_name, p.project_name
from employees e
left join departments d on e.dept_id = d.dept_id
left join projects p on e.emp_id = p.emp_id;
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>emp_name</th><th>dept_name</th><th>project_name</th></tr></thead><tbody><tr><td>Karthik</td><td>HR</td><td>Project A</td></tr><tr><td>Ajay</td><td>HR</td><td>Project B</td></tr><tr><td>Vijay</td><td>IT</td><td>Project C</td></tr><tr><td>Vinay</td><td>IT</td><td>Project D</td></tr><tr><td>Meena</td><td>Finance</td><td>Project E</td></tr><tr><td>Veer</td><td>Marketing</td><td>null</td></tr><tr><td>Keerthi</td><td>Sales</td><td>null</td></tr><tr><td>Priya</td><td>Sales</td><td>null</td></tr></tbody></table></div>

-- %%
--30
select e.emp_name, d.dept_name
from employees e
left join departments d on e.dept_id = d.dept_id;
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>emp_name</th><th>dept_name</th></tr></thead><tbody><tr><td>Karthik</td><td>HR</td></tr><tr><td>Ajay</td><td>HR</td></tr><tr><td>Vijay</td><td>IT</td></tr><tr><td>Vinay</td><td>IT</td></tr><tr><td>Meena</td><td>Finance</td></tr><tr><td>Veer</td><td>Marketing</td></tr><tr><td>Keerthi</td><td>Sales</td></tr><tr><td>Priya</td><td>Sales</td></tr></tbody></table></div>
