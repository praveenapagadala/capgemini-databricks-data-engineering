-- %%
CREATE TABLE employee_salary (
emp_id INT PRIMARY KEY,
emp_name VARCHAR(50),
base_salary DECIMAL(10,2),
bonus DECIMAL(10,2),
tax_percent DECIMAL(5,2),
experience_years INT
);

INSERT INTO employee_salary VALUES
(1, 'Karthik', 75000.75, 5000.50, 10.00, 6),
(2, 'Veena', 65000.40, 4000.25, 8.50, 4),
(3, 'Ravi', 85000.90, 6000.75, 12.00, 8),
(4, 'Anil', 70000.10, NULL, 9.00, 5),
(5, 'Suresh', 60000.55, 3000.30, 7.50, 3);
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>num_affected_rows</th><th>num_inserted_rows</th></tr></thead><tbody><tr><td>5</td><td>5</td></tr></tbody></table></div>

-- %%
-- 1. ABS – Absolute Value
select abs(-100);
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>abs(-100)</th></tr></thead><tbody><tr><td>100</td></tr></tbody></table></div>

-- %%
-- 2. ROUND – Round to Decimals
select round(base_salary, 0) from employee_salary;
select round(base_salary, 2) from employee_salary;
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>round(base_salary,2)</th></tr></thead><tbody><tr><td>75000.75</td></tr><tr><td>65000.40</td></tr><tr><td>85000.90</td></tr><tr><td>70000.10</td></tr><tr><td>60000.55</td></tr></tbody></table></div>

-- %%
-- 3. CEILING / CEIL – Round Up
select ceil(base_salary) from employee_salary;
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>ceil(base_salary)</th></tr></thead><tbody><tr><td>75001</td></tr><tr><td>65001</td></tr><tr><td>85001</td></tr><tr><td>70001</td></tr><tr><td>60001</td></tr></tbody></table></div>

-- %%
-- 4. FLOOR – Round Down
select floor(base_salary) from employee_salary;
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>floor(base_salary)</th></tr></thead><tbody><tr><td>75000</td></tr><tr><td>65000</td></tr><tr><td>85000</td></tr><tr><td>70000</td></tr><tr><td>60000</td></tr></tbody></table></div>

-- %%
-- 5. TRUNCATE – Cut Decimals (No Rounding)
select floor(base_salary * 10) / 10 from employee_salary;
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>floor(base_salary*10)/10</th></tr></thead><tbody><tr><td>75000.700000</td></tr><tr><td>65000.400000</td></tr><tr><td>85000.900000</td></tr><tr><td>70000.100000</td></tr><tr><td>60000.500000</td></tr></tbody></table></div>

-- %%
-- 6. MOD – Remainder
select mod(experience_years, 2) from employee_salary;
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>mod(experience_years,2)</th></tr></thead><tbody><tr><td>0</td></tr><tr><td>0</td></tr><tr><td>0</td></tr><tr><td>1</td></tr><tr><td>1</td></tr></tbody></table></div>

-- %%
-- 7. POWER / POW – Exponent
select pow(2, 3);
select pow(5, 2);
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>pow(5,2)</th></tr></thead><tbody><tr><td>25.0</td></tr></tbody></table></div>

-- %%
-- 8. SQRT – Square Root
select sqrt(64);
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>sqrt(64)</th></tr></thead><tbody><tr><td>8.0</td></tr></tbody></table></div>

-- %%
-- 9. SIGN – Sign of Number
select sign(base_salary) from employee_salary;
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>sign(base_salary)</th></tr></thead><tbody><tr><td>1.0</td></tr><tr><td>1.0</td></tr><tr><td>1.0</td></tr><tr><td>1.0</td></tr><tr><td>1.0</td></tr></tbody></table></div>

-- %%
-- 10. RAND – Random Number
select rand();
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>rand()</th></tr></thead><tbody><tr><td>0.02292474689024926</td></tr></tbody></table></div>

-- %%
-- 11. GREATEST – Maximum Value
select emp_name, greatest(base_salary, IFNULL(bonus, 0)) from employee_salary;
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>emp_name</th><th>greatest(base_salary,IFNULL(bonus,0))</th></tr></thead><tbody><tr><td>Karthik</td><td>75000.75</td></tr><tr><td>Veena</td><td>65000.40</td></tr><tr><td>Ravi</td><td>85000.90</td></tr><tr><td>Anil</td><td>70000.10</td></tr><tr><td>Suresh</td><td>60000.55</td></tr></tbody></table></div>

-- %%
-- 12. LEAST – Minimum Value
select emp_name, least(base_salary, IFNULL(bonus, 0)) from employee_salary;
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>emp_name</th><th>least(base_salary,IFNULL(bonus,0))</th></tr></thead><tbody><tr><td>Karthik</td><td>5000.50</td></tr><tr><td>Veena</td><td>4000.25</td></tr><tr><td>Ravi</td><td>6000.75</td></tr><tr><td>Anil</td><td>0.00</td></tr><tr><td>Suresh</td><td>3000.30</td></tr></tbody></table></div>
